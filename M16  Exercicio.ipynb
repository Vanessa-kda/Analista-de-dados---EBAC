# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Análise Exploratória de Dados de Logística II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Manipulação;</li>
#   <li>Visualização;</li>
#   <li>Storytelling.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# Este *notebook* deve servir como um guia para **você continuar** a construção da sua própria análise exploratória de dados. Fique a vontate para copiar os códigos da aula mas busque explorar os dados ao máximo. Por fim, publique seu *notebook* no [Kaggle](https://www.kaggle.com/).

# %% [markdown]
# ---

# %% [markdown]
# # **Análise Exploratória de Dados de Logística**

# %% [markdown]
# ## 1\. Contexto

# %% [markdown]
# A Loggi é uma empresa brasileira de logística que revolucionou a forma como as encomendas são entregues no pais, fazendo cerca de 500 mil entregas por dia em todo o Brasil, no nosso projeto iremos lidar com os dados de delivery de Brasilia para responder algumas demandas.

# %% [markdown]
# Escreva uma breve descrição do problema.

# %% [markdown]
# ## 2\. Pacotes e bibliotecas

# %%
# !pip3 install geopandas
# !pip install geopy
# Out:
# Requirement already satisfied: geopandas in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (0.9.0)
# Requirement already satisfied: packaging in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (24.0)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (2.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: certifi in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: geopy in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\adm\appdata\local\programs\python\python312\lib\site-packages (from geopy) (2.0)
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import requests
import pandas as pd
import geopandas
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
#Download dos arquivos

# !wget -q "https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/deliveries-geodata.csv" -O deliveries-geodata.csv
# Out:
# 'wget' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %% [markdown]
# ## 3\. Exploração de dados

# %%
## SALVANDO LINK EM UMA PASTA 
# URL do arquivo a ser baixado
url = "https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/deliveries.json"

# Nome do arquivo de destino
filename = "deliveries.json"

# Pasta onde deseja salvar o arquivo (ajuste o caminho conforme necessário)
folder_path = r'C:\Users\adm\OneDrive\ANALISTA_DADOS_EBAC - PYTHON\M16 - Kaggle, storytelling, exploração, tranformação e visualiazção'

# Caminho completo do arquivo
filepath = os.path.join(folder_path, filename)

# Realiza o download do arquivo
response = requests.get(url)

# %%
# Lê o arquivo JSON em um DataFrame Pandas
with open('deliveries.json', mode='r', encoding='utf8') as file:
  data = json.load(file)
deliveries_df = pd.DataFrame(data)

# Extrai as informações do hub de origem e mescla de volta ao DataFrame principal
hub_origin_df = pd.json_normalize(deliveries_df["origin"])
deliveries_df = pd.merge(left=deliveries_df, right=hub_origin_df, how='inner', left_index=True, right_index=True)
deliveries_df = deliveries_df.drop("origin", axis=1) # Remove a coluna 'origin' original
# Seleciona apenas as colunas relevantes para o hub e renomeia algumas para maior clareza
deliveries_df = deliveries_df[["name", "region", "lng", "lat", "vehicle_capacity", "deliveries"]]
deliveries_df.rename(columns={"lng": "hub_lng", "lat": "hub_lat"}, inplace=True)
# "Explode" a coluna 'deliveries' para ter uma linha por entrega individual
deliveries_exploded_df = deliveries_df[["deliveries"]].explode("deliveries")
# Extrai as informações relevantes de cada entrega (tamanho, longitude, latitude)
deliveries_normalized_df = pd.concat([
  pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["size"])).rename(columns={"deliveries": "delivery_size"}),
  pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["point"]["lng"])).rename(columns={"deliveries": "delivery_lng"}),
  pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["point"]["lat"])).rename(columns={"deliveries": "delivery_lat"}),
], axis= 1)
# Remove a coluna 'deliveries' original e mescla as informações normalizadas das entregas
deliveries_df = deliveries_df.drop("deliveries", axis=1)
deliveries_df = pd.merge(left=deliveries_df, right=deliveries_normalized_df, how='right', left_index=True, right_index=True)
# Redefine o índice do DataFrame para facilitar a manipulação posterior
deliveries_df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## 4\. Manipulação

# %%
# faça o código de manipulação de dados:
# - enriquecimento;
# - controle de qualidade;
# - etc.

# %%
# Cria um novo DataFrame (hub_df) contendo apenas as colunas relevantes para os hubs: região, longitude e latitude
hub_df = deliveries_df[["region", "hub_lng", "hub_lat"]]
# Remove linhas duplicadas do DataFrame, garantindo que cada hub seja representado apenas uma vez
hub_df = hub_df.drop_duplicates()
# Ordena o DataFrame pela coluna "region" em ordem alfabética
hub_df = hub_df.sort_values(by="region")
# Redefine o índice do DataFrame para uma sequência numérica simples começando em 0
hub_df = hub_df.reset_index(drop=True)
# Exibe as 5 primeiras linhas do DataFrame resultante para verificar o resultado
hub_df.head()
# Out:
#   region    hub_lng    hub_lat
# 0   df-0 -47.802665 -15.657014
# 1   df-1 -47.893662 -15.805118
# 2   df-2 -48.054989 -15.838145

# %%
# Cria um objeto geolocator do tipo Nominatim, especificando o user_agent
# O user_agent identifica seu aplicativo para o provedor de geocodificação
geolocator = Nominatim(user_agent="wellington_aluno_ebac")
# Cria um objeto geocoder que limita a taxa de chamadas à função geolocator.reverse
# Define um atraso mínimo de 1 segundo entre as chamadas para evitar sobrecarga no serviço
geocoder = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# %%
# Combina as colunas de latitude e longitude em uma única coluna "coordenadas" no formato "latitude, longitude"
hub_df["coordinates"] = hub_df["hub_lat"].astype(str)  + ", " + hub_df["hub_lng"].astype(str)
# Aplica a função geocoder (provavelmente usando o RateLimiter para evitar sobrecarregar o serviço de geocodificação)
# a cada par de coordenadas na coluna "coordenadas". Armazena as informações de localização resultantes na coluna "geodata"
hub_df["geodata"] = hub_df["coordinates"].apply(geocoder)
# Exibe as 5 primeiras linhas do DataFrame para inspecionar os resultados (incluindo as novas colunas "coordenadas" e "geodata")
hub_df.head()
# Out:
#   region    hub_lng    hub_lat                               coordinates  \
# 0   df-0 -47.802665 -15.657014  -15.657013854445248, -47.802664728268745
# 1   df-1 -47.893662 -15.805118    -15.80511751066334, -47.89366206897872
# 2   df-2 -48.054989 -15.838145    -15.83814451122274, -48.05498915846707
#
#                                              geodata
# 0  (Rua 7, Quadra 2, Sobradinho, Região Geográfic...
# 1  (SQS 303, Asa Sul, Brasília, Plano Piloto, Reg...
# 2  (Armazém do Bolo, lote 4/8, CSB 4/5, Taguating...

# %%
# Normalizar os dados brutos de geolocalização (JSON) em um novo DataFrame,
# extraindo informações relevantes como endereço, cidade, estado, país, etc.
hub_geodata_df = pd.json_normalize(hub_df["geodata"].apply(lambda data: data.raw))
hub_geodata_df.head()
# Out:
#    place_id                                            licence osm_type  \
# 0  13551965  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 1  13548034  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 2  10766946  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
#
#        osm_id                  lat                  lon    class         type  \
# 0   240210480  -15.656916027876347   -47.80264463632131  highway    secondary
# 1    66353368  -15.805172757199022  -47.893723539491205  highway  residential
# 2  6249717596          -15.8384371          -48.0552917     shop       pastry
#
#    place_rank  importance  ...     address.state address.ISO3166-2-lvl4  \
# 0          26    0.053343  ...  Distrito Federal                  BR-DF
# 1          26    0.053411  ...  Distrito Federal                  BR-DF
# 2          30    0.000010  ...  Distrito Federal                  BR-DF
#
#         address.region address.postcode address.country address.country_code  \
# 0  Região Centro-Oeste        73015-127          Brasil                   br
# 1  Região Centro-Oeste        70330-400          Brasil                   br
# 2  Região Centro-Oeste        72015-030          Brasil                   br
#
#   address.neighbourhood address.city     address.shop address.house_number
# 0                   NaN          NaN              NaN                  NaN
# 1               SQS 303     Brasília              NaN                  NaN
# 2                   NaN   Taguatinga  Armazém do Bolo             lote 4/8
#
# [3 rows x 31 columns]

# %%
# Seleciona apenas as colunas relevantes para o DataFrame: cidade, bairro e município.
hub_geodata_df = hub_geodata_df[["address.town", "address.suburb", "address.city"]]
# Renomeia as colunas para um formato mais intuitivo, utilizando os prefixos "hub_"
hub_geodata_df.rename(columns={"address.town": "hub_town", "address.suburb": "hub_suburb", "address.city": "hub_city"}, inplace=True)
# Preenche os valores ausentes (NaN) na coluna "hub_city" com os valores correspondentes da coluna "hub_town"
hub_geodata_df["hub_city"] = np.where(hub_geodata_df["hub_city"].notna(), hub_geodata_df["hub_city"], hub_geodata_df["hub_town"])
# Preenche os valores ausentes (NaN) na coluna "hub_suburb" com os valores correspondentes da coluna "hub_city"
hub_geodata_df["hub_suburb"] = np.where(hub_geodata_df["hub_suburb"].notna(), hub_geodata_df["hub_suburb"], hub_geodata_df["hub_city"])
# Remove a coluna "hub_town", pois seus valores já foram utilizados para preencher dados ausentes em outras colunas.
hub_geodata_df = hub_geodata_df.drop("hub_town", axis=1)
# Exibe as primeiras linhas do DataFrame para verificar as alterações e os novos nomes das colunas.
hub_geodata_df.head()
# Out:
#    hub_suburb    hub_city
# 0  Sobradinho  Sobradinho
# 1     Asa Sul    Brasília
# 2  Taguatinga  Taguatinga

# %%
# Combinar o DataFrame original (hub_df) com o DataFrame com os dados de geolocalização (hub_geodata_df)
# A junção é feita com base nos índices (left_index=True, right_index=True) para garantir que as linhas correspondentes sejam combinadas corretamente
hub_df = pd.merge(left=hub_df, right=hub_geodata_df, left_index=True, right_index=True)
# Seleciona apenas as colunas relevantes para o DataFrame: região, bairro e cidade
hub_df = hub_df[["region", "hub_suburb", "hub_city"]]
# Exibe as primeiras linhas do DataFrame para verificar as alterações e os novos nomes das colunas.
hub_df.head()
# Out:
#   region  hub_suburb    hub_city
# 0   df-0  Sobradinho  Sobradinho
# 1   df-1     Asa Sul    Brasília
# 2   df-2  Taguatinga  Taguatinga

# %%
# Combinar o DataFrame de entregas (deliveries_df) com o DataFrame com os dados do hub (hub_df),
# usando a coluna 'region' como chave.
# O tipo de junção é "inner", o que significa que apenas as linhas com valores de 'region' correspondentes em ambos os DataFrames serão incluídas no resultado.
deliveries_df = pd.merge(left=deliveries_df, right=hub_df, how="inner", on="region")
# Seleciona apenas as colunas relevantes do DataFrame resultante: nome, região, longitude e latitude do hub,
# cidade e bairro do hub, capacidade do veículo, tamanho da entrega, e longitude e latitude da entrega.
deliveries_df = deliveries_df[["name", "region", "hub_lng", "hub_lat", "hub_city", "hub_suburb", "vehicle_capacity", "delivery_size", "delivery_lng", "delivery_lat"]]
# Exibe as 5 primeiras linhas do DataFrame resultante para verificar o resultado da junção e seleção das colunas.
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055

# %%
#Salvando link 

# URL do arquivo a ser baixado
url = "https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/deliveries-geodata.csv"

# Nome do arquivo de destino
file_name = 'deliveries-geodata.csv'

# Pasta onde deseja salvar o arquivo (ajuste o caminho conforme necessário)
folder_path = r'C:\Users\adm\OneDrive\ANALISTA_DADOS_EBAC - PYTHON\M16 - Kaggle, storytelling, exploração, tranformação e visualiazção'

# Caminho completo do arquivo
filepath = os.path.join(folder_path, file_name)

# Realiza o download do arquivo
response = requests.get(url)

# Verifica se a requisição foi bem sucedida
if response.status_code == 200:
    # Salva o conteúdo do arquivo no caminho especificado
    with open(filepath, 'wb') as f:
        f.write(response.content)
    print(f"Arquivo '{file_name}' salvo em '{folder_path}'")
else:
    print(f"Falha ao baixar o arquivo. Código de status HTTP: {response.status_code}")
# Out:
# Arquivo 'deliveries-geodata.csv' salvo em 'C:\Users\adm\OneDrive\ANALISTA_DADOS_EBAC - PYTHON\M16 - Kaggle, storytelling, exploração, tranformação e visualiazção'

# %%
# Aqui estamos lendo o arquivo CSV que fizemos download no segundo  logo no cabeçalho deste notebook

deliveries_geodata_df = pd.read_csv(file_name)
deliveries_geodata_df.head()
# Out:
#    delivery_lng  delivery_lat            delivery_city  \
# 0    -48.116189    -15.848929                Ceilândia
# 1    -48.118195    -15.850772                Ceilândia
# 2    -48.112483    -15.847871                Ceilândia
# 3    -48.118023    -15.846471                Ceilândia
# 4    -48.114898    -15.858055  Sol Nascente/Pôr do Sol
#
#            delivery_suburb
# 0                    P Sul
# 1                    P Sul
# 2                    P Sul
# 3                    P Sul
# 4  Sol Nascente/Pôr do Sol

# %%
# Combinar o DataFrame de entregas (deliveries_df) com as informações de cidade e bairro das entregas (deliveries_geodata_df)
# A junção é feita com base nos índices (left_index=True, right_index=True) para garantir que as linhas correspondentes sejam combinadas corretamente.
# Apenas as colunas "delivery_city" e "delivery_suburb" de deliveries_geodata_df são utilizadas.
deliveries_df = pd.merge(left=deliveries_df, right=deliveries_geodata_df[["delivery_city", "delivery_suburb"]], how="inner", left_index=True, right_index=True)
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat  \
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055
#
#              delivery_city          delivery_suburb
# 0                Ceilândia                    P Sul
# 1                Ceilândia                    P Sul
# 2                Ceilândia                    P Sul
# 3                Ceilândia                    P Sul
# 4  Sol Nascente/Pôr do Sol  Sol Nascente/Pôr do Sol

# %%
deliveries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636149 entries, 0 to 636148
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              636149 non-null  object
#  1   region            636149 non-null  object
#  2   hub_lng           636149 non-null  float64
#  3   hub_lat           636149 non-null  float64
#  4   hub_city          636149 non-null  object
#  5   hub_suburb        636149 non-null  object
#  6   vehicle_capacity  636149 non-null  int64
#  7   delivery_size     636149 non-null  int64
#  8   delivery_lng      636149 non-null  float64
#  9   delivery_lat      636149 non-null  float64
#  10  delivery_city     634447 non-null  object
#  11  delivery_suburb   476264 non-null  object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 58.2+ MB

# %%
deliveries_df.isna().any()
# Out:
# name                False
# region              False
# hub_lng             False
# hub_lat             False
# hub_city            False
# hub_suburb          False
# vehicle_capacity    False
# delivery_size       False
# delivery_lng        False
# delivery_lat        False
# delivery_city        True
# delivery_suburb      True
# dtype: bool

# %%
deliveries_df.nunique()
# Out:
# name                   199
# region                   3
# hub_lng                  3
# hub_lat                  3
# hub_city                 3
# hub_suburb               3
# vehicle_capacity         1
# delivery_size           10
# delivery_lng        291566
# delivery_lat        291566
# delivery_city           38
# delivery_suburb        167
# dtype: int64

# %%
var_numericos = []
var_categoricas = []

for coluna in deliveries_df.columns:
  if deliveries_df[coluna].dtype != "object":
    var_numericos.append(coluna)
  else:
    var_categoricas.append(coluna)

print(f'As colunas numéricas são: {var_numericos}')
print(f'As colunas categóricas são: {var_categoricas}')
# Out:
# As colunas numéricas são: ['hub_lng', 'hub_lat', 'vehicle_capacity', 'delivery_size', 'delivery_lng', 'delivery_lat']
# As colunas categóricas são: ['name', 'region', 'hub_city', 'hub_suburb', 'delivery_city', 'delivery_suburb']

# %%
deliveries_df[var_numericos].describe().T
# Out:
#                      count        mean       std         min         25%  \
# hub_lng           636149.0  -47.949902  0.091875  -48.054989  -48.054989
# hub_lat           636149.0  -15.802359  0.053463  -15.838145  -15.838145
# vehicle_capacity  636149.0  180.000000  0.000000  180.000000  180.000000
# delivery_size     636149.0    5.512111  2.874557    1.000000    3.000000
# delivery_lng      636149.0  -47.946087  0.112769  -48.280779  -48.035911
# delivery_lat      636149.0  -15.809492  0.082462  -16.050028  -15.842795
#
#                          50%         75%         max
# hub_lng           -47.893662  -47.893662  -47.802665
# hub_lat           -15.805118  -15.805118  -15.657014
# vehicle_capacity  180.000000  180.000000  180.000000
# delivery_size       6.000000    8.000000   10.000000
# delivery_lng      -47.928967  -47.883394  -47.310611
# delivery_lat      -15.814033  -15.769516  -15.500355

# %% [markdown]
# ## 5\. Visualização

# %%
# faça o código de visualização de dados:
#
# - produza pelo menos duas visualizações;
# - adicione um pequeno texto com os insights encontrados;
# - etc.

# %%
#Aqui fazemos download dos dados direto do ibge.

# !wget -q "https://geoftp.ibge.gov.br/cartas_e_mapas/bases_cartograficas_continuas/bc100/go_df/versao2016/shapefile/bc100_go_df_shp.zip" -O distrito-federal.zip
# !unzip -q distrito-federal.zip -d ./maps
# !cp ./maps/LIM_Unidade_Federacao_A.shp ./distrito-federal.shp
# !cp ./maps/LIM_Unidade_Federacao_A.shx ./distrito-federal.shx
# Out:
# 'wget' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.
# 'unzip' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.
# 'cp' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.
# 'cp' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %%
import os
import zipfile
import geopandas as gpd
import requests

# URL do arquivo ZIP a ser baixado
url = "https://geoftp.ibge.gov.br/cartas_e_mapas/bases_cartograficas_continuas/bc100/go_df/versao2016/shapefile/bc100_go_df_shp.zip"

# Nome do arquivo ZIP de destino
zip_file_name = 'bc100_go_df_shp.zip'

# Pasta onde deseja salvar o arquivo ZIP e extrair os shapefiles
folder_path = r'C:\Users\adm\OneDrive\ANALISTA_DADOS_EBAC - PYTHON\M16 - Kaggle, storytelling, exploração, tranformação e visualiazção'

# Caminho completo do arquivo ZIP
zip_filepath = os.path.join(folder_path, zip_file_name)

# Realiza o download do arquivo ZIP
response = requests.get(url)

# Verifica se a requisição foi bem sucedida
if response.status_code == 200:
    # Salva o conteúdo do arquivo ZIP no caminho especificado
    with open(zip_filepath, 'wb') as f:
        f.write(response.content)
    print(f"Arquivo '{zip_file_name}' salvo em '{folder_path}'")
else:
    print(f"Falha ao baixar o arquivo. Código de status HTTP: {response.status_code}")

# Verifica se o arquivo ZIP foi baixado e está disponível para extração
if os.path.exists(zip_filepath):
    try:
        # Extrai o conteúdo do arquivo ZIP para a pasta de destino
        with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
            zip_ref.extractall(folder_path)
        print(f"Arquivo ZIP '{zip_file_name}' extraído com sucesso em '{folder_path}'")
        
        # Listar arquivos extraídos
        extracted_files = zip_ref.namelist()
        shapefile_path = None
        for file in extracted_files:
            if file.endswith('.shp'):
                shapefile_path = os.path.join(folder_path, file)
                break
        
        if shapefile_path:
            # Carrega o shapefile usando GeoPandas
            mapa = gpd.read_file(shapefile_path)
            print("GeoDataFrame carregado com sucesso:")
            print(mapa.head())
        else:
            print("Nenhum arquivo shapefile encontrado na extração.")
        
    except Exception as e:
        print(f"Erro ao extrair ou carregar shapefile: {str(e)}")
else:
    print(f"Erro: O arquivo ZIP '{zip_file_name}' não foi encontrado em '{folder_path}'.")
# Out:
# Arquivo 'bc100_go_df_shp.zip' salvo em 'C:\Users\adm\OneDrive\ANALISTA_DADOS_EBAC - PYTHON\M16 - Kaggle, storytelling, exploração, tranformação e visualiazção'
# Arquivo ZIP 'bc100_go_df_shp.zip' extraído com sucesso em 'C:\Users\adm\OneDrive\ANALISTA_DADOS_EBAC - PYTHON\M16 - Kaggle, storytelling, exploração, tranformação e visualiazção'
# GeoDataFrame carregado com sucesso:
#    ID_ANTIGO                  NOME NOMEABREV GEOMETRIAA    TIPOCEMITE  \
# 0          3                  None      None        Não  Desconhecido
# 1          5                  None      None        Não  Desconhecido
# 2         19  Jardim da Consolação      None        Não  Desconhecido
# 3         10    Campo da Esperança      None        Não  Desconhecido
# 4         16                  None      None        Não  Desconhecido
#
#    DENOMINACA  ID_PRODUTO  ID_ELEMENT TX_COMENTA  \
# 0         NaN         NaN         NaN       None
# 1         NaN         NaN         NaN       None
# 2         NaN         NaN         NaN       None
# 3         NaN         NaN         NaN       None
# 4         NaN         NaN         NaN       None
#
#                                             geometry
# 0  POLYGON Z ((-53.19467 -17.34088 0, -53.19425 -...
# 1  POLYGON Z ((-48.09035 -15.7985 0, -48.08518 -1...
# 2  POLYGON Z ((-47.98377 -16.26566 0, -47.98372 -...
# 3  POLYGON Z ((-47.93095 -15.82183 0, -47.93111 -...
# 4  POLYGON Z ((-47.98799 -16.09335 0, -47.98534 -...

# %%
hub_df = deliveries_df[["region", "hub_lng", "hub_lat"]].drop_duplicates().reset_index(drop=True)
geo_hub_df = geopandas.GeoDataFrame(hub_df, geometry=geopandas.points_from_xy(hub_df["hub_lng"], hub_df["hub_lat"]))
geo_hub_df.head()
# Out:
#   region    hub_lng    hub_lat                     geometry
# 0   df-2 -48.054989 -15.838145  POINT (-48.05499 -15.83814)
# 1   df-1 -47.893662 -15.805118  POINT (-47.89366 -15.80512)
# 2   df-0 -47.802665 -15.657014  POINT (-47.80266 -15.65701)

# %%
geo_deliveries_df = geopandas.GeoDataFrame(deliveries_df, geometry=geopandas.points_from_xy(deliveries_df["delivery_lng"], deliveries_df["delivery_lat"]))
geo_deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat  \
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055
#
#              delivery_city          delivery_suburb  \
# 0                Ceilândia                    P Sul
# 1                Ceilândia                    P Sul
# 2                Ceilândia                    P Sul
# 3                Ceilândia                    P Sul
# 4  Sol Nascente/Pôr do Sol  Sol Nascente/Pôr do Sol
#
#                       geometry
# 0  POINT (-48.11619 -15.84893)
# 1  POINT (-48.11819 -15.85077)
# 2  POINT (-48.11248 -15.84787)
# 3  POINT (-48.11802 -15.84647)
# 4   POINT (-48.1149 -15.85805)

# %%
# cria o plot vazio
fig, ax = plt.subplots(figsize = (20, 20))

# plot mapa do distrito federal
mapa.plot(ax=ax, alpha=0.4, color="lightgrey")

# plot das entregas
geo_deliveries_df.query("region == 'df-0'").plot(ax=ax, markersize=1, color="red", label="df-0")
geo_deliveries_df.query("region == 'df-1'").plot(ax=ax, markersize=1, color="blue", label="df-1")
geo_deliveries_df.query("region == 'df-2'").plot(ax=ax, markersize=1, color="seagreen", label="df-2")

# plot dos hubs
geo_hub_df.plot(ax=ax, markersize=60, marker="x", color="black", label="hub")

ax.set_xlim(-48.5, -47.5)
ax.set_ylim(-16.5, -15.5)


# plot da legenda
plt.title("Entregas no Distrito Federal por Região", fontdict={"fontsize": 16})
lgnd = plt.legend(prop={"size": 15})
for handle in lgnd.legendHandles:
    handle.set_sizes([50])
# Out:
# C:\Users\adm\AppData\Local\Temp\ipykernel_10488\2330076573.py:22: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in lgnd.legendHandles:

# %% [markdown]
# O hub zero(0) tem muitas entregas distantes uma das outras.
# O hub dois(2) tambem possuiu entregas espaçadas uma das outras, porém menos que o hub zero(0)
# O hub um (1) Esta com as entregas bem centralizadas.
